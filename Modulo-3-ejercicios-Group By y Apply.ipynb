# %% [markdown]
# # Ejercicios

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("merchant_fill.csv", index_col=0)
df.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold  uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100               0         3.76            54               26.0
# 1       20000               1         3.45          6135             2269.0
# 2        1000               1         3.83            99               43.0
# 3         100               0         3.77            47               22.0
# 4         100               1         2.86             7                1.0
#
# ...

# %%
df.columns
# Out:
# Index(['title', 'price', 'retail_price', 'units_sold', 'uses_ad_boosts',
#        'rating_sold', 'rating_count', 'rating_five_count', 'rating_four_count',
#        'rating_three_count', 'rating_two_count', 'rating_one_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'origin_country',
#        'merchant_name', 'merchant_info_subtitle', 'merchant_rating_count',
#        'merchant_rating', 'merchant_id', 'product_url', 'product_id',
#        'listed_products', 'total_units_sold', 'mean_units_sold_per_product',
#        'rating_employee', 'merchant_ratings_count', 'mean_product_prices',
#        'mean_retail_prices', 'average_discount', 'mean_discount',
#        'mean_product_ratings_count'],
#       dtype='object')

# %% [markdown]
# Índice(['título', 'precio', 'precio_de_venta', 'unidades_vendidas', 'usos_aumentos_de_anuncio',
# 'calificación_vendida', 'número_de_calificación', 'número_de_calificación_cinco', 'número_de_calificación_cuatro',
# 'número_de_calificación_tres', 'número_de_calificación_dos', 'número_de_calificación_uno',
# 'insignia_producto_local', 'insignia_calidad_del_producto', 'insignia_envío_rápido',
# 'etiquetas', 'color_del_producto', 'id_de_tamaño_variación_del_producto',
# 'nombre_de_opción_de_envío', 'precio_de_opción_de_envío', 'envío_exprés',
# 'países_a_los_que_se_envía', 'total_de_inventario', 'país_de_origen',
# 'nombre_del_comerciante', 'subtítulo_de_información_del_comerciante', 'recuento_calificación_comerciante',
# 'calificación_comerciante', 'id_comerciante', 'url_producto', 'id_producto',
# 'productos_publicados', 'unidades_totales_vendidas', 'unidades_vendidas_media_por_producto',
# 'calificación_empleado', 'recuento_calificaciones_comerciante', 'precios_medios_producto',
# 'precios_medios_venta_venta', 'descuento_promedio', 'descuento_medio',
# 'recuento_calificaciones_medias_producto'],
# dtype='object')

# %% [markdown]
# 1. Total de unidades vendidas por país de origen del vendedor. Debéis agrupar los datos según el país de origen del vendedor y calcular el total de unidades vendidas para cada país. Esto nos dará una idea de qué países tienen una mayor participación en las ventas totales y cuáles tienen menos. Devuelve los resultados en un DataFrame ordenados de mayor a menor en función de la cantidad de unidades vendidas.

# %%
country_total_sold = df.groupby("origin_country")["total_units_sold"].mean()
country_total_sold
# Out:
# origin_country
# AT      100.000000
# CN    11458.867414
# GB     1000.000000
# SG    20100.000000
# US     1950.322581
# VE      130.000000
# Name: total_units_sold, dtype: float64

# %%
df1 = country_total_sold.reset_index()
df1
# Out:
#   origin_country  total_units_sold
# 0             AT        100.000000
# 1             CN      11458.867414
# 2             GB       1000.000000
# 3             SG      20100.000000
# 4             US       1950.322581
# 5             VE        130.000000

# %%
df1 = df1.sort_values(by='total_units_sold', ascending=False)
df1
# Out:
#   origin_country  total_units_sold
# 3             SG      20100.000000
# 1             CN      11458.867414
# 4             US       1950.322581
# 2             GB       1000.000000
# 5             VE        130.000000
# 0             AT        100.000000

# %% [markdown]
# 2. Estadísticas de precio por país de envío. Vamos a explorar el precio promedio y el precio máximo de los productos según el país al que se envían. Al hacer esto, podremos entender cómo varían los precios según el destino del envío y si hay alguna tendencia interesante que valga la pena analizar. Devuelve los resultados en un DataFrame.

# %%
estadistica_precio = df.groupby("countries_shipped_to")["price"].agg(["mean", "max"])
estadistica_precio
# Out:
#                            mean   max
# countries_shipped_to
# 6                      6.000000   6.0
# 8                      5.298333   6.0
# 9                      6.707500   8.0
# 10                    12.111429  18.0
# 11                     8.500000  12.0
# ...                         ...   ...
# 135                    5.355000   7.0
# 137                    8.243333  11.0
# 138                    6.036667   9.0
# 139                    8.975000  13.0
# 140                    5.220000   7.0
#
# [94 rows x 2 columns]

# %% [markdown]
# 3. Conteo de productos con y sin distintivo de producto local. Vamos a clasificar los productos según si tienen o no un distintivo de producto local. Luego, calcularemos el conteo de productos en cada categoría para comprender cuántos productos tienen este distintivo y cuántos no. Esto puede proporcionarnos información sobre cómo se promocionan los productos con esta característica. Devuelve los resultados en un DataFrame.

# %%
df.groupby("badge_local_product")["title"].count().reset_index()
# Out:
#    badge_local_product  title
# 0                    0   1544
# 1                    1     29

# %% [markdown]
# 4. Promedio de unidades vendidas por tipo de envío. Nuestro objetivo es analizar cómo se correlaciona el tipo de envío (columna shipping_option_name ) con las unidades vendidas. Vamos a calcular el promedio de unidades vendidas para cada tipo de opción de envío. Esto podría ayudarnos a determinar si ciertos métodos de envío están relacionados con un mayor o menor rendimiento en las ventas. Devuelve los resultados en un DataFrame. ¿Qué conclusiones puedes sacar de este resultado?

# %%
estadistica_unidades = df.groupby("shipping_option_name")["units_sold"].agg(["mean", "median", "std", "var", "min", "max"])
estadistica_unidades
# Out:
#                                  mean   median          std           var  \
# shipping_option_name
# Ekspresowa wysyłka       10000.000000  10000.0          NaN           NaN
# Envio Padrão              2488.888889   1000.0  3469.309890  1.203611e+07
# Envío normal              3220.000000   5000.0  2458.048006  6.042000e+06
# Expediere Standard         400.000000    100.0   464.758002  2.160000e+05
# Livraison Express          400.000000    100.0   519.615242  2.700000e+05
# Livraison standard        4383.756631   1000.0  9498.482781  9.022118e+07
# Spedizione standard        550.000000    550.0   636.396103  4.050000e+05
# Standard Shipping         4216.666667   1000.0  6263.651757  3.923333e+07
# Standardowa wysyłka      10033.333333  10000.0  9950.041876  9.900333e+07
# Standardversand            100.000000    100.0     0.000000  0.000000e+00
# Standart Gönderi          5500.000000   5500.0  6363.961031  4.050000e+07
# ...

# %% [markdown]
# 5. Reemplazo de valores. A lo largo del DataFrame tenemos algunas columnas cuyos valores son cero y uno, lo que podría llevar a confusión en su interpretación. Estas columnas son:

# %%
"""uses_ad_boosts: La cual indica si la plataforma de comercio electrónico ha utilizado o no la función de impulso de anuncios. 
Si el valor de uses_ad_boosts es 1, indica que el vendedor ha invertido en publicidad adicional para resaltar el producto. 
Si el valor es 0, no ha sido promocionado a través de anuncios adicionales."""

diccionario_mapa = {0: "No", 1: "Si"}

df["uses_ad_boosts"] = df["uses_ad_boosts"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 205  2019 Mode pour femmes Maillots de bain Deux pi...   5.83             5
# 330  2020 Women Ladies Fashion Plus Size Summer Tie...  16.00            14
# 510  Women Summer Printed Plus Size Loose Casual Tr...  11.00            10
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 205       10000             Si         4.22          2055             1162.0
# 330         100             Si         3.73            89               39.0
# 510         100             Si         3.54            13                5.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 205              488.0               212.0              83.0
# 330               21.0                10.0               4.0
# 510                3.0                 1.0               2.0
#
#      rating_one_count  badge_local_product  badge_product_quality  \
# ...

# %%
df["uses_ad_boosts"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
"""badge_local_product: Indica que el producto se produce, fabrica o se envía desde la misma región o país en el que se realiza la transacción de compra. 
Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto local. 
Si el valor es 0, indica que el producto no tiene este distintivo."""

diccionario_mapa = {0: "No", 1: "Si"}

df["badge_local_product"] = df["badge_local_product"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 938  Nouveau mode hommes pantalons d'été pantalons ...    5.0             8
# 819  100 pcs Été Jetable Sweat Pad Transpiration Ab...    9.0            46
# 903  Mode Femmes Dos Nu Sans Bretelles Sexy Dames B...   11.0            83
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 938        5000             Si         3.51           747              270.0
# 819         100             No         4.86             7                6.0
# 903       20000             No         3.87          5719             2720.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 938              138.0               157.0              64.0
# 819                1.0                 0.0               0.0
# 903             1171.0               820.0             408.0
#
#      rating_one_count badge_local_product  badge_product_quality  \
# ...

# %%
df["badge_local_product"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
"""badge_product_quality: Indica que el producto cumple con ciertos estándares de calidad, características o evaluaciones positivas por parte de los consumidores. 
Si el valor es 1, significa que el producto tiene un distintivo que lo califica como un producto de alta calidad. 
Si el valor es 0, indica que el producto no tiene este distintivo de calidad."""

diccionario_mapa = {0: "No", 1: "Si"}

df["badge_product_quality"] = df["badge_product_quality"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 422  Hommes été bloc de couleur imprimé poitrine po...    8.0            17
# 932  2019 Mode féminine Hot Summer Fashion Flare Sl...   11.0            10
# 584  Women's Summer Fashion Spaghetti Strap Dress F...    8.0             7
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 422        1000             No         3.96           288              133.0
# 932         100             No         3.96            98               46.0
# 584          50             No         3.88             8                5.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 422               75.0                39.0              18.0
# 932               24.0                14.0               6.0
# 584                1.0                 0.0               0.0
#
#      rating_one_count badge_local_product badge_product_quality  \
# ...

# %%
df["badge_product_quality"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
"""badge_fast_shipping: Indica que el producto se enviará y entregará en un plazo más corto en comparación con otras opciones de envío estándar. 
Si el valor es 1, significa que el producto tiene un distintivo que indica un envío rápido. 
Si el valor es 0, indica que el producto no tiene este distintivo de envío rápido."""

diccionario_mapa = {0: "No", 1: "Si"}

df["badge_fast_shipping"] = df["badge_fast_shipping"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 101  Summer Fashion Women Sexy Lace Strap Shirt Top...   5.00             5
# 956  XS-6XL Nouvelle Mode Femmes D'été O-Cou Sans M...   3.76             4
# 902  S-XXL Mode Eté Printemps Femme Elastique Taill...  12.00            81
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 101         100             No         4.50             6                4.0
# 956        1000             No         3.34            95               33.0
# 902       20000             No         4.08          1799              960.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 101                1.0                 1.0               0.0
# 956               17.0                15.0               9.0
# 902              346.0               285.0              97.0
#
#      rating_one_count badge_local_product badge_product_quality  \
# ...

# %%
df["badge_fast_shipping"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %%
"""shipping_is_express: Se refiere a si una opción de envío para un producto en una plataforma de comercio electrónico se considera como "envío exprés" o "envío rápido". 
Si el valor es 1, significa que la opción de envío asociada se considera como una entrega rápida o exprés. 
Si el valor es 0, indica que la opción de envío no se considera como envío exprés."""

diccionario_mapa = {0: "No", 1: "Si"}

df["shipping_is_express"] = df["shipping_is_express"].map(diccionario_mapa)

df.sample(3)
# Out:
#                                                  title  price  retail_price  \
# 229  Summer Women Fashion Fashion Robe courte sans ...   8.00            51
# 264  Women Summer Off Shoulder V-neck Bow Top Top C...   5.66             5
# 475  2020 NOUVELLES Femmes Ensembles Courts D'été S...   8.00             7
#
#      units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 229         100             No         4.29            31               19.0
# 264        5000             No         3.89          1161              558.0
# 475         100             Si         4.57             7                5.0
#
#      rating_four_count  rating_three_count  rating_two_count  \
# 229                5.0                 5.0               1.0
# 264              242.0               159.0              75.0
# 475                1.0                 1.0               0.0
#
#      rating_one_count badge_local_product badge_product_quality  \
# ...

# %%
df["shipping_is_express"].unique()
# Out:
# array(['No', 'Si'], dtype=object)

# %% [markdown]
# 6. Calificación de la calidad del producto. Sobreescribe la columna badge_product_quality utilizando apply() para asignar "Buena" a las filas donde 'badge_product_quality' sea "No" y "Excelente" donde sea "Si".

# %%
def categorizar_quality(palabra):
    
    if palabra == "No":
        return "Buena"
    
    elif palabra == "Si":
        return "Excelente"
    
    else:
        return None

# %%
df["badge_product_quality"] = df["badge_product_quality"].apply(categorizar_quality)

df.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
#
# ...

# %%
df["badge_product_quality"].unique()
# Out:
# array(['Buena', 'Excelente'], dtype=object)

# %% [markdown]
# 7. Cálculo de descuento. Crea una nueva columna discount_percentage utilizando apply() que calcule el porcentaje de descuento basado en las columnas 'price' y 'retail_price', redondea los decimales a 2. Después elimina las columnas de average_discount y mean_discount

# %%
def calcular_discount_percentage(col_price, col_retail):
    
    discount_percentage = round((col_retail - col_price) * 100 / col_retail,2)
    return str(discount_percentage)

# aplicar la función al DataFrame usando un apply y un lambda
df["discount_percentage"] = df.apply(lambda x: calcular_discount_percentage(x["price"], x["retail_price"]), axis = 1)

# mostrar el DataFrame para ver si se creo correctamente la columna
df.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
#
# ...

# %%
df.drop(["average_discount", "mean_discount"], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...    8.0            22
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
#
#   badge_local_product badge_product_quality badge_fast_shipping  \
# 0                  No                 Buena                  No
# 1                  No                 Buena                  No
#
#                                                 tags product_color  \
# ...

# %% [markdown]
# 8. Evaluación de la valoración del vendedor. Utiliza apply() para crear una nueva columna 'seller_reputation' donde los valores sean "Buena" si 'merchant_rating' es mayor o igual a 4, y "Regular" si es menor a 4. Después elimina la columna merchant_rating.

# %%
def categorizar_seller(valoracion):

    if valoracion >= 4:
        return "Buena"
    
    elif valoracion < 4:
        return "Regular"
    
    else:
        return None

# %%
df["seller_reputation"] = df["merchant_rating"].apply(categorizar_seller)

# chequeamos que se ha creado la columna nueva (siempre aparecerá al final del DataFrame)
df.head()
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...   8.00            22
# 2  Nouvelle mode d'été femmes robe décontractée c...   4.90             8
# 3   Summer Women s Fashion Lace Up Tie Pants Plus...   4.93             6
# 4  Nouvelle mode d'été femmes robe décontractée c...   5.65            10
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
# 2        1000             Si         3.83            99               43.0
# 3         100             No         3.77            47               22.0
# 4         100             Si         2.86             7                1.0
#
# ...

# %%
df.drop(["merchant_rating"], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...    8.0            22
#
#    units_sold uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100             No         3.76            54               26.0
# 1       20000             Si         3.45          6135             2269.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
#
#   badge_local_product badge_product_quality badge_fast_shipping  \
# 0                  No                 Buena                  No
# 1                  No                 Buena                  No
#
#                                                 tags product_color  \
# ...

# %%
df.to_csv("merchant_fill_clean.csv")
